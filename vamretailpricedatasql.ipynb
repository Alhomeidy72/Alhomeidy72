#  13  2022-01-10 00:00:00  850 non-null    float64
#  14  2022-01-17 00:00:00  850 non-null    float64
# ...

# %%
data.dtypes
# Out:
# Province                object
# IPC category            object
# Commodity               object
# 2021-11-01 00:00:00    float64
# 2021-11-08 00:00:00    float64
#                         ...
# 2023-08-07 00:00:00    float64
# 2023-08-14 00:00:00    float64
# 2023-08-21 00:00:00    float64
# 2023-08-28 00:00:00    float64
# 2023-09-04 00:00:00    float64
# Length: 100, dtype: object

# %%
data.isna().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True]])

# %%
data.dropna(axis =1, inplace=True)

# %%
data.isna().sum()
# Out:
# Province                0
# IPC category            0
# Commodity               0
# 2021-11-01 00:00:00     0
# 2021-11-08 00:00:00     0
#                        ..
# 2023-08-07 00:00:00    22
# 2023-08-14 00:00:00    23
# 2023-08-21 00:00:00    23
# 2023-08-28 00:00:00    21
# 2023-09-04 00:00:00    21
# Length: 100, dtype: int64

# %%
import datetime
columns_to_rename = data.columns[3:]
new_column_names=[pd.to_datetime(col).strftime("%Y %b Week %U") for col in columns_to_rename]
data.rename(columns=dict(zip(columns_to_rename,new_column_names)), inplace=True)

# %%
data.columns
# Out:
# Index(['Province', 'IPC category', 'Commodity', '2021 Nov Week 44',
#        '2021 Nov Week 45', '2021 Nov Week 46', '2021 Nov Week 47',
#        '2021 Nov Week 48', '2021 Dec Week 49', '2021 Dec Week 50',
#        '2021 Dec Week 51', '2021 Dec Week 52', '2022 Jan Week 01',
#        '2022 Jan Week 02', '2022 Jan Week 03', '2022 Jan Week 04',
#        '2022 Jan Week 05', '2022 Feb Week 06', '2022 Feb Week 07',
#        '2023 Feb Week 09', '2023 Mar Week 10', '2023 Mar Week 11',
#        '2023 Apr Week 14'],
#       dtype='object')

# %%
price_trend=data.groupby(["Province","Commodity"]).sum().reset_index()
# Out:
# <ipython-input-33-756403964c49>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   price_trend=data.groupby(["Province","Commodity"]).sum().reset_index()

# %%
price_trend.head()
# Out:
#      Province                         Commodity  2021 Nov Week 44  \
# 0  Badakhshan                LABOUR SKILLED/DAY             666.0
# 1  Badakhshan              LABOUR UNSKILLED/DAY             250.0
# 2  Badakhshan     # OF DAYS WORK AVAILABLE/WEEK               1.0
# 3  Badakhshan  ANIMAL FEED (CONCENTRATE) 100 Kg            4433.3
# 4  Badakhshan                    BREAD     (Kg)              69.0
#
#    2021 Nov Week 45  2021 Nov Week 46  2021 Nov Week 47  2021 Nov Week 48  \
# 0             666.0             666.0             666.0             666.0
# 1             250.0             250.0             250.0             250.0
# 2               1.0               1.0               1.0               1.0
# 3            4433.3            4433.3            4433.3            4433.3
# 4              69.0              69.0              71.4              71.4
#
#    2021 Dec Week 49  2021 Dec Week 50  2021 Dec Week 51  2021 Dec Week 52  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
